# %%
import pandas as pd
import numpy as np
from ast import literal_eval

# %%
meta = pd.read_csv("data/movies_metadata.csv", low_memory=False)
credits = pd.read_csv('data/credits.csv')
keywords = pd.read_csv('data/keywords.csv')

# %%
meta.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
meta['genres'] = meta['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
meta['production_companies']= meta['production_companies'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
meta['production_countries'] = meta['production_countries'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
meta['spoken_languages'] = meta['spoken_languages'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
meta['year'] = pd.to_datetime(meta['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
keywords['id'] = keywords['id'].astype('int')
credits['id'] = credits['id'].astype('int')
meta = meta.drop([19730, 29503, 35587])
meta['id'] = meta['id'].astype('int')

# %%
meta = meta.merge(credits, on='id')
meta = meta.merge(keywords, on='id')
meta['cast'] = meta['cast'].apply(literal_eval)
meta['crew'] = meta['crew'].apply(literal_eval)
meta['keywords'] = meta['keywords'].apply(literal_eval)
meta['cast_size'] = meta['cast'].apply(lambda x: len(x))
meta['crew_size'] = meta['crew'].apply(lambda x: len(x))

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

meta['director'] = meta['crew'].apply(get_director)

# %%
meta['cast'] = meta['cast'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
meta['cast'] = meta['cast'].apply(lambda x: x[:4] if len(x) >=4 else x)
meta['keywords'] = meta['keywords'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
meta['cast'] = meta['cast'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
meta['director'] = meta['director'].astype('str').apply(lambda x: str.lower(x.replace(" ", "")))

# %%
meta.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ...  video vote_average  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  False          7.7
# 1  When siblings Judy and Peter discover an encha...  ...  False          6.9
# 2  A family wedding reignites the ancient feud be...  ...  False          6.5
# 3  Cheated on, mistreated and stepped on, the wom...  ...  False          6.1
# 4  Just when George Banks has recovered from his ...  ...  False          5.7
#
#   vote_count  year                                               cast  \
# 0     5415.0  1995        [tomhanks, timallen, donrickles, jimvarney]
# 1     2413.0  1995  [robinwilliams, jonathanhyde, kirstendunst, br...
# 2       92.0  1995  [waltermatthau, jacklemmon, ann-margret, sophi...
# 3       34.0  1995  [whitneyhouston, angelabassett, lorettadevine,...
# 4      173.0  1995  [stevemartin, dianekeaton, martinshort, kimber...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords cast_size crew_size  \
# 0  [jealousy, toy, boy, friendship, friends, riva...        13       106
# 1  [board game, disappearance, based on children'...        26        16
# 2  [fishing, best friend, duringcreditsstinger, o...         7         4
# 3  [based on novel, interracial relationship, sin...        10        10
# 4  [baby, midlife crisis, confidence, aging, daug...        12         7
#
#          director
# 0    johnlasseter
# 1     joejohnston
# 2    howarddeutch
# 3  forestwhitaker
# 4    charlesshyer
#
# [5 rows x 31 columns]

# %%
meta = meta.sort_values('vote_average', ascending=False)
meta.head()
# Out:
#        adult belongs_to_collection budget                      genres  \
# 22543  False                   NaN      0     [Mystery, Crime, Drama]
# 3187   False                   NaN      0               [Documentary]
# 36822  False                   NaN      0  [Drama, Action, Adventure]
# 14513  False                   NaN    130               [Documentary]
# 22250  False                   NaN      0                          []
#
#       homepage      id    imdb_id original_language  \
# 22543      NaN  388182  tt2669832                fa
# 3187       NaN   49477  tt0192069                en
# 36822      NaN  211139  tt0058289                en
# 14513      NaN  234937  tt0906743                en
# 22250      NaN  143534  tt0015493                en
#
#                                           original_title  \
# 22543                                     هیچ کجا هیچ کس
# 3187   Gendernauts: A Journey Through Shifting Identi...
# 36822                                      Leone di Tebe
# 14513                                            Forever
# 22250                                   The White Shadow
#
#                                                 overview  ...  video  \
# 22543                                                NaN  ...  False
# 3187   Monika Treut explores the worlds and thoughts ...  ...  False
# 36822  Fleeing Troy in the wake of its destruction, f...  ...  False
# 14513  Père-Lachaise - one of the world's most famous...  ...  False
# 22250  The White Shadow is a British drama film direc...  ...  False
#
#       vote_average vote_count  year  \
# 22543         10.0        1.0  2013
# 3187          10.0        2.0  1999
# 36822         10.0        1.0  1964
# 14513         10.0        1.0  2006
# 22250         10.0        1.0  1924
#
#                                                     cast  \
# 22543  [mohammadrezaforutan, mahnazafshar, saberabar,...
# 3187                                                  []
# 36822  [markforest, yvonnefurneaux, massimoserato, pi...
# 14513                    [yoshinokimura, bertrandbeyern]
# 22250  [bettycompson, clivebrook, henryvictor, a.b.im...
#
#                                                     crew  \
# 22543  [{'credit_id': '56eadbd5925141388d00011a', 'de...
# 3187   [{'credit_id': '532c85cec3a3685fac0000c8', 'de...
# 36822  [{'credit_id': '5486b30892514176030010bc', 'de...
# 14513  [{'credit_id': '52fe4e3cc3a36847f82853ff', 'de...
# 22250  [{'credit_id': '52fe4b0e9251416c750f6d65', 'de...
#
#                                                 keywords cast_size crew_size  \
# 22543                                          [iranian]         8         3
# 3187                              [lgbt, woman director]         0         1
# 36822                         [sword and sandal, peplum]         7        10
# 14513  [cemetery, artist, grave, interview, woman dir...         2         1
# 22250                                            [twins]         5         8
#
#               director
# 22543  ebrahimsheibani
# 3187       monikatreut
# 36822   giorgioferroni
# 14513   heddyhonigmann
# 22250      grahamcutts
#
# [5 rows x 31 columns]

# %%
vote_counts = meta[meta['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = meta[meta['vote_average'].notnull()]['vote_average'].astype('int')

C = vote_averages.mean()
m = vote_counts.quantile(0.96)

def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_movies = meta.copy().loc[meta['vote_count'] >= m]
q_movies.shape
# Out:
# (1866, 31)

# %%
q_movies['weight_score'] = q_movies.apply(weighted_rating, axis=1)

# %%
q_movies = q_movies.sort_values('weight_score', ascending=False)
q_movies[['title', 'vote_count', 'vote_average', 'weight_score']].head(20)
# Out:
#                                                title  vote_count  \
# 314                         The Shawshank Redemption      8358.0
# 841                                    The Godfather      6024.0
# 12589                                The Dark Knight     12269.0
# 2870                                      Fight Club      9678.0
# 292                                     Pulp Fiction      8670.0
# 351                                     Forrest Gump      8147.0
# 15651                                      Inception     14075.0
# 23076                                   Interstellar     11187.0
# 522                                 Schindler's List      4436.0
# 23868                                       Whiplash      4376.0
# 1175                         The Empire Strikes Back      5998.0
# 18655                               The Intouchables      5410.0
# 5529                                   Spirited Away      3968.0
# 7069   The Lord of the Rings: The Return of the King      8226.0
# 2231                               Life Is Beautiful      3643.0
# 256                                        Star Wars      6778.0
# 1199                          The Godfather: Part II      3418.0
# 289                           Leon: The Professional      4293.0
# 46                                             Se7en      5915.0
# 3057                                  The Green Mile      4166.0
#
#        vote_average  weight_score
# 314             8.5      8.293154
# 841             8.5      8.219894
# 12589           8.3      8.165002
# 2870            8.3      8.130857
# 292             8.3      8.112397
# 351             8.2      8.007633
# 15651           8.1      7.989386
# 23076           8.1      7.962206
# 522             8.3      7.953599
# 23868           8.3      7.949393
# 1175            8.2      7.944653
# 18655           8.2      7.919529
# 5529            8.3      7.917843
# 7069            8.1      7.915799
# 2231            8.3      7.888335
# 256             8.1      7.879480
# 1199            8.3      7.865086
# 289             8.2      7.855053
# 46              8.1      7.850116
# 3057            8.2      7.845795

# %%
features = ['keywords','cast','genres','director']

for feature in features:
   meta[feature] = meta[feature].fillna('')

def combine_features(row):
    keywords = " ".join(row['keywords'])
    genres = " ".join(row['genres'])
    try:
        return keywords +" "+row['cast']+" "+genres+" "+row["director"]
    except:
        return genres + keywords

meta["combined_features"] = meta.apply(combine_features,axis=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

cv = CountVectorizer()
count_matrix = cv.fit_transform(meta["combined_features"])

cosine_sim = cosine_similarity(count_matrix) 
sim_df = pd.DataFrame(cosine_sim, index=meta.title, columns=meta.title)
sim_df.head()
# Out:
# title                                               هیچ کجا هیچ کس  \
# title
# هیچ کجا هیچ کس                                                 1.0
# Gendernauts: A Journey Through Shifting Identities             0.0
# The Lion of Thebes                                             0.0
# Forever                                                        0.0
# The White Shadow                                               0.0
#
# title                                               Gendernauts: A Journey Through Shifting Identities  \
# title
# هیچ کجا هیچ کس                                                                               0.000000
# Gendernauts: A Journey Through Shifting Identities                                           1.000000
# The Lion of Thebes                                                                           0.000000
# Forever                                                                                      0.471405
# The White Shadow                                                                             0.000000
#
# title                                               The Lion of Thebes  \
# title
# هیچ کجا هیچ کس                                                     0.0
# Gendernauts: A Journey Through Shifting Identities                 0.0
# The Lion of Thebes                                                 1.0
# Forever                                                            0.0
# The White Shadow                                                   0.0
#
# title                                                Forever  \
# title
# هیچ کجا هیچ کس                                      0.000000
# Gendernauts: A Journey Through Shifting Identities  0.471405
# The Lion of Thebes                                  0.000000
# Forever                                             1.000000
# The White Shadow                                    0.000000
#
# title                                               The White Shadow  Macbeth  \
# title
# هیچ کجا هیچ کس                                                   0.0      0.0
# Gendernauts: A Journey Through Shifting Identities               0.0      0.0
# The Lion of Thebes                                               0.0      0.0
# Forever                                                          0.0      0.0
# The White Shadow                                                 1.0      0.0
#
# title                                               Claymation Comedy of Horrors  \
# title
# هیچ کجا هیچ کس                                                               0.0
# Gendernauts: A Journey Through Shifting Identities                           0.0
# The Lion of Thebes                                                           0.0
# Forever                                                                      0.0
# The White Shadow                                                             0.0
#
# title                                               Birch Interval  \
# title
# هیچ کجا هیچ کس                                            0.000000
# Gendernauts: A Journey Through Shifting Identities        0.000000
# The Lion of Thebes                                        0.408248
# Forever                                                   0.000000
# The White Shadow                                          0.000000
#
# title                                               Birch Interval  \
# title
# هیچ کجا هیچ کس                                            0.000000
# Gendernauts: A Journey Through Shifting Identities        0.000000
# The Lion of Thebes                                        0.408248
# Forever                                                   0.000000
# The White Shadow                                          0.000000
#
# title                                               Vessel of Wrath  ...  \
# title                                                                ...
# هیچ کجا هیچ کس                                             0.000000  ...
# Gendernauts: A Journey Through Shifting Identities         0.000000  ...
# The Lion of Thebes                                         0.204124  ...
# Forever                                                    0.000000  ...
# The White Shadow                                           0.000000  ...
#
# title                                               A Small Act  \
# title
# هیچ کجا هیچ کس                                         0.000000
# Gendernauts: A Journey Through Shifting Identities     0.408248
# The Lion of Thebes                                     0.000000
# Forever                                                0.288675
# The White Shadow                                       0.000000
#
# title                                               24 Hours On Craigslist  \
# title
# هیچ کجا هیچ کس                                                         0.0
# Gendernauts: A Journey Through Shifting Identities                     0.0
# The Lion of Thebes                                                     0.0
# Forever                                                                0.0
# The White Shadow                                                       0.0
#
# title                                               The Genius of Marie Curie: The Woman Who Lit up the World  \
# title
# هیچ کجا هیچ کس                                                                                    0.0
# Gendernauts: A Journey Through Shifting Identities                                                0.0
# The Lion of Thebes                                                                                0.0
# Forever                                                                                           0.0
# The White Shadow                                                                                  0.0
#
# title                                               The Mole at the Sea  \
# title
# هیچ کجا هیچ کس                                                      0.0
# Gendernauts: A Journey Through Shifting Identities                  0.0
# The Lion of Thebes                                                  0.0
# Forever                                                             0.0
# The White Shadow                                                    0.0
#
# title                                               Paul Taylor Creative Domain  \
# title
# هیچ کجا هیچ کس                                                         0.000000
# Gendernauts: A Journey Through Shifting Identities                     0.577350
# The Lion of Thebes                                                     0.000000
# Forever                                                                0.408248
# The White Shadow                                                       0.000000
#
# title                                               Queerama       NaN  \
# title
# هیچ کجا هیچ کس                                           0.0  0.000000
# Gendernauts: A Journey Through Shifting Identities       0.0  0.000000
# The Lion of Thebes                                       0.0  0.204124
# Forever                                                  0.0  0.000000
# The White Shadow                                         0.0  0.000000
#
# title                                                    NaN       NaN  \
# title
# هیچ کجا هیچ کس                                      0.149071  0.000000
# Gendernauts: A Journey Through Shifting Identities  0.000000  0.000000
# The Lion of Thebes                                  0.000000  0.096225
# Forever                                             0.000000  0.000000
# The White Shadow                                    0.000000  0.000000
#
# title                                                    NaN
# title
# هیچ کجا هیچ کس                                      0.000000
# Gendernauts: A Journey Through Shifting Identities  0.000000
# The Lion of Thebes                                  0.096225
# Forever                                             0.000000
# The White Shadow                                    0.000000
#
# [5 rows x 46628 columns]

# %%
movie_user_likes = "Avatar"
sim_df[movie_user_likes].sort_values(ascending=False)[:20]
# Out:
# title
# Avatar                                1.000000
# Rogue One: A Star Wars Story          0.560404
# Babylon 5: A Call to Arms             0.542326
# Icarus XB 1                           0.532291
# Mr. Blot in Space                     0.529256
# Alien³                                0.516150
# Star Wreck: In the Pirkinning         0.514877
# Crash of Moons                        0.513436
# Aliens                                0.511310
# Planet of the Apes                    0.511310
# Star Trek Into Darkness               0.509427
# Approaching the Unknown               0.506171
# Dante 01                              0.504878
# Mission to Mars                       0.504101
# Journey to the Far Side of the Sun    0.494312
# Alien                                 0.490098
# Mission to Mir                        0.477665
# Conquest of Space                     0.476331
# Moonraker                             0.475349
# Prince of Space                       0.457330
# Name: Avatar, dtype: float64

# %%
movie_user_likes = "Toy Story"
sim_df[movie_user_likes].sort_values(ascending=False)[:20]
# Out:
# title
# Toy Story                          1.000000
# Toy Story 3                        0.526077
# Small Soldiers                     0.520000
# Pinocchio                          0.417029
# Ted                                0.404145
# Child's Play                       0.402492
# Barbie and the Three Musketeers    0.400000
# Child's Play 2                     0.400000
# Toy Story 2                        0.395132
# The Indian in the Cupboard         0.361814
# Toy Story That Time Forgot         0.357771
# Hawaiian Vacation                  0.353553
# Toys                               0.353553
# Halfaouine: Boy of the Terraces    0.346410
# Life-Size                          0.339550
# Alma                               0.339550
# Ted 2                              0.332820
# Home Alone 3                       0.329983
# Trolls                             0.326599
# Monster House                      0.316228
# Name: Toy Story, dtype: float64

# %%
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

ratings = pd.read_csv("data/ratings_small.csv")
ratings = ratings[["userId", "movieId", "rating"]]
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0
